# %%
import pandas as pd

# %%
광산구 = pd.read_csv('광산구_박수정.csv', index_col = 0)

# %%
광산구

# %%
서구 = pd.read_csv('서구_박수정.csv',index_col = 0)

# %%
서구

# %%
서구 = 서구.transpose()

# %%
서구

# %%
서구.to_csv('서구_최종.csv',index=False,encoding = 'utf-8')

# %%
서구.to_csv('서구_최종2.csv',index=True,encoding = 'cp949')

# %%
북구 = pd.read_csv('북구_박수정.csv',index_col=0)
남구 = pd.read_csv('남구_박수정.csv',index_col=0)
동구 = pd.read_csv('동구_박수정.csv',index_col=0)

# %%
북구 = 북구.transpose()

# %%
남구 = 남구.transpose()

# %%
동구 = 동구.transpose()

# %%
북구.to_csv('북구_최종.csv',index=True,encoding = 'cp949')
남구.to_csv('남구_최종.csv',index=True,encoding = 'cp949')
동구.to_csv('동구_최종.csv',index=True,encoding = 'cp949')

# %%
광산구 = pd.read_csv('광산구_박수정.csv', index_col = 0)

# %%
광산구
# Out:
#               합계    송정동    도산동    신흥동     어령동     우산동     월곡동    비아동     첨단동  \
# 구분
# 총 계      165,914  6,420  6,107  1,600  13,210  10,594  10,728  2,585  51,376
# 10월 14일   25,956    713    764    199   1,919     942    1436    373   6,700
# 10세        5,260    140    151     43     433     178     276     85    1305
# 11세        5,020    140    132     37     357     221     251     65    1223
# 12세        5,107    119    140     25     413     179     303     75    1293
# 13세        5,582    154    183     46     367     188     321     71    1483
# 14세        4,987    160    158     48     349     176     285     77    1396
# 15-19     26,550    877    897    231   1,743   1,149    1786    397   8,274
# 15세        4,855    146    149     35     355     184     315     64    1387
# 16세        5,128    160    164     52     326     222     324     84    1600
# 17세        5,457    154    187     50     364     237     410     69    1613
# ...

# %%
광산구.transpose()
# Out:
# 구분       총 계 10월 14일    10세    11세    12세    13세    14세   15-19    15세    16세  \
# 합계   165,914  25,956  5,260  5,020  5,107  5,582  4,987  26,550  4,855  5,128
# 송정동    6,420     713    140    140    119    154    160     877    146    160
# 도산동    6,107     764    151    132    140    183    158     897    149    164
# 신흥동    1,600     199     43     37     25     46     48     231     35     52
# 어령동   13,210   1,919    433    357    413    367    349   1,743    355    326
# 우산동   10,594     942    178    221    179    188    176   1,149    184    222
# 월곡동   10,728    1436    276    251    303    321    285    1786    315    324
# 비아동    2,585     373     85     65     75     71     77     397     64     84
# 첨단동   51,376   6,700   1305   1223   1293   1483   1396   8,274   1387   1600
# 신가동    8,044   1,394    267    298    259    298    272   1,525    255    302
# 운남동   12,822   1,877    367    373    356    417    364   2,106    357    415
# ...

# %%
광산구.to_csv('광산구_최종.csv',index=True,encoding = 'cp949')
