# %%
import pandas as pd

# %%
자전거 = pd.read_csv('타랑께_박수정.csv',index_col = 0)

# %%
자전거
# Out:
#                     출발시각        열2      열1            도착시각   출발보관대   도착보관대  \
# 자전거ID
# GJA-0141  20200701082504  20200701   82504  20200701083128  D-0021  D-0022
# GJA-0073  20200701112145  20200701  112145  20200701122435  D-0020  D-0015
# GJA-0169  20200701113432  20200701  113432  20200701114431  D-0018  D-0020
# GJA-0183  20200701114006  20200701  114006  20200701115905  D-0018  D-0020
# GJA-0166  20200701124544  20200701  124544  20200701125442  D-0018  D-0035
# ...                  ...       ...     ...             ...     ...     ...
# GJA-0115  20210205135943  20210205  135943  20210205140711  D-0035  D-0025
# GJA-0050  20210205141152  20210205  141152  20210205142957  D-0031  D-0035
# GJA-0089  20210205141641  20210205  141641  20210205153052  D-0022  D-0020
# GJA-0035  20210205145055  20210205  145055  20210205184054  D-0000  D-0039
# GJA-0063  20210205151252  20210205  151252  20210205161137  D-0017  D-0000
#
#            사용시간          출발지          도착지
# 자전거ID
# ...

# %%
내자전거 = 자전거.loc[:, ['출발시각', '도착시각']]

# %%
내자전거
# Out:
#                     출발시각            도착시각
# 자전거ID
# GJA-0141  20200701082504  20200701083128
# GJA-0073  20200701112145  20200701122435
# GJA-0169  20200701113432  20200701114431
# GJA-0183  20200701114006  20200701115905
# GJA-0166  20200701124544  20200701125442
# ...                  ...             ...
# GJA-0115  20210205135943  20210205140711
# GJA-0050  20210205141152  20210205142957
# GJA-0089  20210205141641  20210205153052
# GJA-0035  20210205145055  20210205184054
# GJA-0063  20210205151252  20210205161137
#
# [10865 rows x 2 columns]

# %%
내자전거.index
# Out:
# Index(['GJA-0141', 'GJA-0073', 'GJA-0169', 'GJA-0183', 'GJA-0166', 'GJA-0073',
#        'GJA-0105', 'GJA-0121', 'GJA-0120', 'GJA-0045',
#        ...
#        'GJA-0157', 'GJA-0007', 'GJA-0153', 'GJA-0137', 'GJA-0098', 'GJA-0115',
#        'GJA-0050', 'GJA-0089', 'GJA-0035', 'GJA-0063'],
#       dtype='object', name='자전거ID', length=10865)

# %%
type(내자전거)

# %%
내자전거.loc[:]['출발시각']
# Out:
# 자전거ID
# GJA-0141    20200701082504
# GJA-0073    20200701112145
# GJA-0169    20200701113432
# GJA-0183    20200701114006
# GJA-0166    20200701124544
#                  ...
# GJA-0115    20210205135943
# GJA-0050    20210205141152
# GJA-0089    20210205141641
# GJA-0035    20210205145055
# GJA-0063    20210205151252
# Name: 출발시각, Length: 10865, dtype: int64

# %%
내자전거.columns
# Out:
# Index(['출발시각', '도착시각'], dtype='object')

# %%
자전거_출발 = 내자전거['출발시각']

# %%
자전거_출발
# Out:
# 자전거ID
# GJA-0141    20200701082504
# GJA-0073    20200701112145
# GJA-0169    20200701113432
# GJA-0183    20200701114006
# GJA-0166    20200701124544
#                  ...
# GJA-0115    20210205135943
# GJA-0050    20210205141152
# GJA-0089    20210205141641
# GJA-0035    20210205145055
# GJA-0063    20210205151252
# Name: 출발시각, Length: 10865, dtype: int64

# %%
자전거_도착 = 내자전거['도착시각']

# %%
자전거_도착
# Out:
# 자전거ID
# GJA-0141    20200701083128
# GJA-0073    20200701122435
# GJA-0169    20200701114431
# GJA-0183    20200701115905
# GJA-0166    20200701125442
#                  ...
# GJA-0115    20210205140711
# GJA-0050    20210205142957
# GJA-0089    20210205153052
# GJA-0035    20210205184054
# GJA-0063    20210205161137
# Name: 도착시각, Length: 10865, dtype: int64

# %%
자전거_도착 =자전거_도착.astype('str')

# %%
from dateutil.parse import parse

# %%
pip install parser

# %%
import datetime

# %%
자전거_출발[1]
# Out:
# 20200701112145

# %%
자전거_출발[0]

# %%
자전거_출발[len(자전거_출발)-1]
# Out:
# 20210205151252

# %%
for i in 자전거_출발:
    date = i
    date_str = str(date)
    datetime.datetime.strptime(date_str,'%Y-%m-%d %H:%M:%S')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-f590b928ccc7> in <module>
#       2     date = i
#       3     date_str = str(date)
# ----> 4     datetime.datetime.strptime(date_str,'%Y-%m-%d %H:%M:%S')
#
# ~\anaconda3\lib\_strptime.py in _strptime_datetime(cls, data_string, format)
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# ~\anaconda3\lib\_strptime.py in _strptime(data_string, format)
#     347     found = format_regex.match(data_string)
#     348     if not found:
# --> 349         raise ValueError("time data %r does not match format %r" %
#     350                          (data_string, format))
# ...

# %%
자전거_출발

# %%
자전거_출발 =자전거_출발.astype('str')

# %%
자전거_출발

# %%
import numpy as np
df = pd.concat([자전거_출발,자전거_도착])

# %%
df

# %%
자전거_출발 = 자전거_출발.tolist()

# %%
자전거_출발

# %%
자전거_출발.info
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-763948697d9a> in <module>
# ----> 1 자전거_출발.info
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'info'

# %%
from datetime import date,datetime,time

test_date = 자전거_출발[0]

# %%
test_date
# Out:
# 20200701082504

# %%
c_date = datetime.datetime.strptime(test_date,"%Y%m%d%H%M%S")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-352660dcaaab> in <module>
# ----> 1 c_date = datetime.datetime.strptime(test_date,"%Y%m%d%H%M%S")
#
# AttributeError: type object 'datetime.datetime' has no attribute 'datetime'

# %%
c_date

# %%
a = c_date
a

# %%
df_list=[]
for i in 자전거_출발 :
    date = i
    c_date = datetime.strptime(date,"%Y%m%d%H%M%S")
    c_date=c_date.strftime('%Y-%m-%d %H:%M:%S')
    df_list.append(c_date)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-a6ed71089a7e> in <module>
#       2 for i in 자전거_출발 :
#       3     date = i
# ----> 4     c_date = datetime.strptime(date,"%Y%m%d%H%M%S")
#       5     c_date=c_date.strftime('%Y-%m-%d %H:%M:%S')
#       6     df_list.append(c_date)
#
# TypeError: strptime() argument 1 must be str, not int

# %%
df_list

# %%
자전거_도착 =자전거_도착.astype('str')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-136-443dbfbaa9dc> in <module>
# ----> 1 자전거_도착 =자전거_도착.astype('str')
#
# AttributeError: 'list' object has no attribute 'astype'

# %%
자전거_도착 = 자전거_도착.tolist()

# %%
자전거_도착
# Out:
# [20200701083128,
#  20200701122435,
#  20200701114431,
#  20200701115905,
#  20200701125442,
#  20200701144258,
#  20200701141849,
#  20200701145333,
#  20200701145445,
#  20200701151417,
#  20200701172620,
#  20200701163733,
#  20200701154126,
#  20200701171141,
#  20200701174805,
#  20200701174629,
#  20200701174647,
#  20200701175131,
#  20200701182319,
#  20200701190735,
#  20200701181932,
#  20200701183904,
#  20200701183913,
#  20200701184028,
#  20200701184401,
#  20200701190124,
#  20200701190028,
#  20200701190050,
#  20200701193644,
#  20200701194905,
#  20200701202438,
#  20200701220704,
#  20200702090944,
#  20200702100131,
#  20200702102211,
#  20200702102210,
#  20200702102414,
#  20200702110631,
#  20200702115149,
#  20200702124327,
#  20200702130201,
#  20200702124845,
#  20200702135105,
#  20200702144253,
#  20200702134417,
#  20200702140354,
#  20200702162113,
#  20200702160252,
#  20200702152922,
#  20200702153125,
#  20200702153125,
#  20200702153137,
# ...

# %%
df_list_3=[]
for a in 자전거_도착 :
    date_a = a
    c_date = datetime.strptime(date_a,"%Y%m%d%H%M%S")
    c_date=c_date.strftime('%Y-%m-%d %H:%M:%S')
    df_list_3.append(c_date)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-4b6808b3f142> in <module>
#       2 for a in 자전거_도착 :
#       3     date_a = a
# ----> 4     c_date = datetime.strptime(date_a,"%Y%m%d%H%M%S")
#       5     c_date=c_date.strftime('%Y-%m-%d %H:%M:%S')
#       6     df_list_3.append(c_date)
#
# TypeError: strptime() argument 1 must be str, not int

# %%
df_list_3
# Out:
# []

# %%
자전거_시간 = pd.DateFrame([df_list,df_list3])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-81863f069c46> in <module>
# ----> 1 자전거_시간 = pd.DateFrame([df_list,df_list3])
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'DateFrame'

# %%
df_출발 = pd.DataFrame(df_list)

# %%
df_출발
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
자전거.loc[:,['자전거ID']]

# %%
자전거.columns

# %%
김자전거 = pd.read_csv('타랑께_김수정.csv')

# %%
김자전거.columns

# %%
자전거id=김자전거.loc[:, ['자전거ID']]

# %%
자전거id

# %%
df_도착 = pd.DataFrame(df_list_3)

# %%
df_도착

# %%
자전거_시간 = pd.DateFrame([df_list,df_list_2],columns=자전거id)

# %%
자전거_시간 = pd.concat([df_출발,df_도착],axis=1)

# %%
자전거_시간

# %%
자전거_시간.columns = ['출발시각','도착시각']

# %%
자전거_시간.columns
# Out:
# Index(['출발시각', '도착시각'], dtype='object')

# %%
자전거_시간

# %%
자전거_시간_임시=자전거_시간.T

# %%
자전거_시간_임시 = 자전거_시간_임시.columns = 자전거id

# %%
자전거_시간
# Out:
#                       출발시각                 도착시각
# 0      2020-07-01 08:25:04  2020-07-01 08:31:28
# 1      2020-07-01 11:21:45  2020-07-01 12:24:35
# 2      2020-07-01 11:34:32  2020-07-01 11:44:31
# 3      2020-07-01 11:40:06  2020-07-01 11:59:05
# 4      2020-07-01 12:45:44  2020-07-01 12:54:42
# ...                    ...                  ...
# 10860  2021-02-05 13:59:43  2021-02-05 14:07:11
# 10861  2021-02-05 14:11:52  2021-02-05 14:29:57
# 10862  2021-02-05 14:16:41  2021-02-05 15:30:52
# 10863  2021-02-05 14:50:55  2021-02-05 18:40:54
# 10864  2021-02-05 15:12:52  2021-02-05 16:11:37
#
# [10865 rows x 2 columns]

# %%
자전거_시간_임시 = 자전거_시간

# %%
자전거_시간_임시.loc[:'소요시각'] = 자전거_시간_임시.loc[:'도착시각'] -자전거_시간_임시.loc[:'출발시각']

# %%
for i in range(len(df_list)):
    df_list[i] = datetime.strptime(df_list[i] , '%Y%m%d%H%M%S')

# %%
자전거_시간.transpose()
# Out:
#                     0                    1                    2      \
# 출발시각  2020-07-01 08:25:04  2020-07-01 11:21:45  2020-07-01 11:34:32
# 도착시각  2020-07-01 08:31:28  2020-07-01 12:24:35  2020-07-01 11:44:31
#
#                     3                    4                    5      \
# 출발시각  2020-07-01 11:40:06  2020-07-01 12:45:44  2020-07-01 13:42:32
# 도착시각  2020-07-01 11:59:05  2020-07-01 12:54:42  2020-07-01 14:42:58
#
#                     6                    7                    8      \
# 출발시각  2020-07-01 14:00:48  2020-07-01 14:10:01  2020-07-01 14:10:13
# 도착시각  2020-07-01 14:18:49  2020-07-01 14:53:33  2020-07-01 14:54:45
#
#                     9      ...                10855                10856  \
# 출발시각  2020-07-01 14:12:44  ...  2021-02-05 12:45:05  2021-02-05 12:49:30
# 도착시각  2020-07-01 15:14:17  ...  2021-02-05 12:53:16  2021-02-05 12:54:29
#
#                     10857                10858                10859  \
# ...

# %%
자전거_시간_결론= 자전거_시간.transpose()

# %%
자전거_시간_결론.loc['소요시각'] = 자전거_시간_결론.loc['도착시각'] - 자전거_시간_결론.loc['출발시각']

# %%
자전거_시간_결론 = 자전거_시간_결론.transpose()

# %%
depart = 자전거_시간_결론['출발시각']

# %%
depart = depart.values.tolist()
for i in range(len(depart)):
    depart[i] = datetime.strptime(depart[i] , '%Y-%m-%d %H:%M:%S')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-168-4c5ab0de9316> in <module>
# ----> 1 depart = depart.values.tolist()
#       2 for i in range(len(depart)):
#       3     depart[i] = datetime.strptime(depart[i] , '%Y-%m-%d %H:%M:%S')
#
# AttributeError: 'list' object has no attribute 'values'

# %%
자전거_시간_결론['출발시각'] = pd.to_datetime(자전거_시간_결론['출발시각'])

# %%
자전거_시간_결론['출발시각']
# Out:
# 0       2020-07-01 08:25:04
# 1       2020-07-01 11:21:45
# 2       2020-07-01 11:34:32
# 3       2020-07-01 11:40:06
# 4       2020-07-01 12:45:44
#                 ...
# 10860   2021-02-05 13:59:43
# 10861   2021-02-05 14:11:52
# 10862   2021-02-05 14:16:41
# 10863   2021-02-05 14:50:55
# 10864   2021-02-05 15:12:52
# Name: 출발시각, Length: 10865, dtype: datetime64[ns]

# %%
자전거_시간_결론['도착시각'] = pd.to_datetime(자전거_시간_결론['도착시각'])

# %%
자전거_시간_결론['도착시각']
# Out:
# 0       2020-07-01 08:31:28
# 1       2020-07-01 12:24:35
# 2       2020-07-01 11:44:31
# 3       2020-07-01 11:59:05
# 4       2020-07-01 12:54:42
#                 ...
# 10860   2021-02-05 14:07:11
# 10861   2021-02-05 14:29:57
# 10862   2021-02-05 15:30:52
# 10863   2021-02-05 18:40:54
# 10864   2021-02-05 16:11:37
# Name: 도착시각, Length: 10865, dtype: datetime64[ns]

# %%
자전거_시간_결론
# Out:
#                      출발시각                도착시각
# 0     2020-07-01 08:25:04 2020-07-01 08:31:28
# 1     2020-07-01 11:21:45 2020-07-01 12:24:35
# 2     2020-07-01 11:34:32 2020-07-01 11:44:31
# 3     2020-07-01 11:40:06 2020-07-01 11:59:05
# 4     2020-07-01 12:45:44 2020-07-01 12:54:42
# ...                   ...                 ...
# 10860 2021-02-05 13:59:43 2021-02-05 14:07:11
# 10861 2021-02-05 14:11:52 2021-02-05 14:29:57
# 10862 2021-02-05 14:16:41 2021-02-05 15:30:52
# 10863 2021-02-05 14:50:55 2021-02-05 18:40:54
# 10864 2021-02-05 15:12:52 2021-02-05 16:11:37
#
# [10865 rows x 2 columns]

# %%
자전거_시간_결론 = 자전거_시간_결론.transpose()

# %%
자전거_시간_결론
# Out:
#                    0                   1                   2      \
# 출발시각 2020-07-01 08:25:04 2020-07-01 11:21:45 2020-07-01 11:34:32
# 도착시각 2020-07-01 08:31:28 2020-07-01 12:24:35 2020-07-01 11:44:31
#
#                    3                   4                   5      \
# 출발시각 2020-07-01 11:40:06 2020-07-01 12:45:44 2020-07-01 13:42:32
# 도착시각 2020-07-01 11:59:05 2020-07-01 12:54:42 2020-07-01 14:42:58
#
#                    6                   7                   8      \
# 출발시각 2020-07-01 14:00:48 2020-07-01 14:10:01 2020-07-01 14:10:13
# 도착시각 2020-07-01 14:18:49 2020-07-01 14:53:33 2020-07-01 14:54:45
#
#                    9      ...               10855               10856  \
# 출발시각 2020-07-01 14:12:44  ... 2021-02-05 12:45:05 2021-02-05 12:49:30
# 도착시각 2020-07-01 15:14:17  ... 2021-02-05 12:53:16 2021-02-05 12:54:29
#
#                    10857               10858               10859  \
# 출발시각 2021-02-05 13:34:48 2021-02-05 13:46:07 2021-02-05 13:57:46
# ...

# %%
자전거_시간_결론.loc['사용시간'] = 자전거_시간_결론.loc['도착시각']- 자전거_시간_결론.loc['출발시각']

# %%
자전거_시간_결론
# Out:
#                     0                    1                    2      \
# 출발시각  2020-07-01 08:25:04  2020-07-01 11:21:45  2020-07-01 11:34:32
# 도착시각  2020-07-01 08:31:28  2020-07-01 12:24:35  2020-07-01 11:44:31
# 사용시간      0 days 00:06:24      0 days 01:02:50      0 days 00:09:59
#
#                     3                    4                    5      \
# 출발시각  2020-07-01 11:40:06  2020-07-01 12:45:44  2020-07-01 13:42:32
# 도착시각  2020-07-01 11:59:05  2020-07-01 12:54:42  2020-07-01 14:42:58
# 사용시간      0 days 00:18:59      0 days 00:08:58      0 days 01:00:26
#
#                     6                    7                    8      \
# 출발시각  2020-07-01 14:00:48  2020-07-01 14:10:01  2020-07-01 14:10:13
# 도착시각  2020-07-01 14:18:49  2020-07-01 14:53:33  2020-07-01 14:54:45
# 사용시간      0 days 00:18:01      0 days 00:43:32      0 days 00:44:32
#
#                     9      ...                10855                10856  \
# ...

# %%
자전거_시간_결론 = 자전거_시간_결론.transpose()

# %%
자전거_시간_결론
# Out:
#                      출발시각                도착시각            사용시간
# 0     2020-07-01 08:25:04 2020-07-01 08:31:28 0 days 00:06:24
# 1     2020-07-01 11:21:45 2020-07-01 12:24:35 0 days 01:02:50
# 2     2020-07-01 11:34:32 2020-07-01 11:44:31 0 days 00:09:59
# 3     2020-07-01 11:40:06 2020-07-01 11:59:05 0 days 00:18:59
# 4     2020-07-01 12:45:44 2020-07-01 12:54:42 0 days 00:08:58
# ...                   ...                 ...             ...
# 10860 2021-02-05 13:59:43 2021-02-05 14:07:11 0 days 00:07:28
# 10861 2021-02-05 14:11:52 2021-02-05 14:29:57 0 days 00:18:05
# 10862 2021-02-05 14:16:41 2021-02-05 15:30:52 0 days 01:14:11
# 10863 2021-02-05 14:50:55 2021-02-05 18:40:54 0 days 03:49:59
# 10864 2021-02-05 15:12:52 2021-02-05 16:11:37 0 days 00:58:45
#
# [10865 rows x 3 columns]

# %%
자전거_시간_결론.to_csv('자전거_사용시간.csv',index=True,encoding='cp949')
