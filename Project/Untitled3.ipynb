# %%
import pandas as pd

# %%
광산구 = pd.read_csv('광산구_최종.csv',index_col = 0,encoding='cp949')

# %%
광산구 = 광산구.T

# %%
광산구
# Out:
# 구분        총계 10월 14일    10세    11세    12세    13세    14세   15-19    15세    16세  \
# 합계   165,914  25,956  5,260  5,020  5,107  5,582  4,987  26,550  4,855  5,128
# 송정동    6,420     713    140    140    119    154    160     877    146    160
# 도산동    6,107     764    151    132    140    183    158     897    149    164
# 신흥동    1,600     199     43     37     25     46     48     231     35     52
# 어령동   13,210   1,919    433    357    413    367    349   1,743    355    326
# 우산동   10,594     942    178    221    179    188    176   1,149    184    222
# 월곡동   10,728    1436    276    251    303    321    285    1786    315    324
# 비아동    2,585     373     85     65     75     71     77     397     64     84
# 첨단동   51,376   6,700   1305   1223   1293   1483   1396   8,274   1387   1600
# 신가동    8,044   1,394    267    298    259    298    272   1,525    255    302
# 운남동   12,822   1,877    367    373    356    417    364   2,106    357    415
# ...

# %%
광산구=광산구.T

# %%
광산구

# %%
광산구.loc['총계']

# %%
광산구_최종 = 광산구.loc['총계']

# %%
광산구_최종

# %%
광산구_최종=pd.DataFrame(광산구_최종)

# %%
광산구_최종.to_csv('광산구_진짜최종.csv',index=True,encoding='cp949')

# %%
서구 = pd.read_csv('서구_최종2.csv',index_col = 0,encoding='cp949')
동구 = pd.read_csv('동구_최종.csv',index_col = 0,encoding='cp949')
북구 = pd.read_csv('북구_최종.csv',index_col = 0,encoding='cp949')
남구 = pd.read_csv('남구_최종.csv',index_col = 0,encoding='cp949')

# %%
서구
# Out:
#           총계 10월 14일    10세    11세    12세    13세    14세   15-19    15세    16세  \
# 합계   113,600  14,547  2,810  2,746  2,893  3,135  2,963  17,020  2,843  3,187
# 양동     2,413     261     68     48     42     52     51     252     46     48
# 농성동    5,664     402     76     67     94     85     80     537     77     98
# 광천동    2,782     265     52     56     57     50     50     364     43     58
# 유덕동    4,417     594    126    112    120    125    111     706    105    131
# 치평동   12,989   1,400    260    285    291    294    270   1,716    276    302
# 상무동   19,884   1,880    341    331    391    388    429   2,342    394    435
# 화정동   23,649    2975    605    582    554    638    596    3187    566    605
# 서창동    1,858     177     25     41     40     34     37     240     34     44
# 금호동   18,869    2889    522    543    558    649    617   3,648    623    696
# 풍암동   14,971   2,423    455    446    501    526    495   2,852    476    517
# ...

# %%
서구_총계=서구.T.loc['총계']

# %%
pd.DataFrame(서구_총계)
# Out:
#           총계
# 합계   113,600
# 양동     2,413
# 농성동    5,664
# 광천동    2,782
# 유덕동    4,417
# 치평동   12,989
# 상무동   19,884
# 화정동   23,649
# 서창동    1,858
# 금호동   18,869
# 풍암동   14,971
# 동천동    6,104

# %%
서구_총계.to_csv('서구_진짜최종.csv',index=True,encoding='cp949')

# %%
남구_총계=남구.T.loc['총계']
pd.DataFrame(남구_총계)
남구_총계.to_csv('남구_진짜최종.csv',index=True,encoding='cp949')

# %%
남구_총계.T
# Out:
# 합계     76,272
# 양림동     2,282
# 방림동     5,372
# 봉선동    16,127
# 사직동     1,597
# 월산동     7,050
# 백운동     6,440
# 주월동     9,740
# 효덕동    17,847
# 송암동     8,316
# 대촌동     1,501
# Name: 총계, dtype: object
