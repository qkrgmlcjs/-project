# %%
#타랑께 평일
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
a = pd.read_csv('전국인구데이터.csv',index_col = 0,encoding = 'cp949') #데이터 불러오기
df = pd.DataFrame(a)
df
# Out:
#          MEGA_CD CTY_NM  CTY_CD  X_AXIS  Y_AXIS   HOUS    POP  POP_10  POP_20  \
# MEGA_NM
# 경기도           41    여주군   41730  365950  526450  10.08  24.56    4.64    1.92
# 경기도           41    여주군   41730  371250  524250   1.42   3.47    0.81    0.29
# 경기도           41    여주군   41730  372750  523050   1.26   3.08    0.68    0.28
# 경기도           41    여주군   41730  361850  515750  10.08  25.20    3.68    2.96
# 경기도           41    여주군   41730  360650  516250   3.78   9.45    1.38    1.11
# ...          ...    ...     ...     ...     ...    ...    ...     ...     ...
# 전라북도          45    익산시   45140  304550  371450   7.04  18.59    3.52    1.87
# 전라남도          46    해남군   46820  262750  210250   6.15  12.15    1.30    0.00
# 전라북도          45    완주군   45710  319750  347150   1.83   4.53    1.92    0.24
# 경기도           41   남양주시   41360  327550  555650   2.38   5.31    0.91    0.74
# 경기도           41    여주군   41730  366350  524650   1.26   3.07    0.58    0.24
#
# ...

# %%
df2 = df.loc['광주광역시']

# %%
동구_인구수=df2[df2.loc[:,'CTY_NM']=='동구']

# %%
동구_인구수.to_csv("동구_인구수.csv",encoding = 'cp949')
